# %% [markdown]
# Tema2
# Lidia Istrate
# 342C4

# %% [markdown]
# Functions for reading the input:

# %%
import re


#Representation
CONSTANT = 1
VARIABLE = 2
FUNCTION = 3
ATOM = 4
CONDITION = 5
RULE = 6
QUESTION = 7
ANSWER = 8




def make_const(value):
    return (CONSTANT, value)


def make_var(name):
    return (VARIABLE, name)


def make_function_call(function, *args):
    return (FUNCTION, function, list(args))


def make_atom(predicate, *args):
    return (ATOM, predicate, list(args))


def make_question(predicate, *args):
    return (QUESTION, predicate, list(args))

#conditie
def make_condition(sentence1, sentence2, *others):
    return (CONDITION, CONDITION, [sentence1] + [sentence2] + list(others))

def make_rule(atom, condition):
    return (RULE, atom, condition)


def is_constant(f):
    return f[0] == CONSTANT


def is_variable(f):
    return f[0] == VARIABLE


def is_function_call(f):
    return f[0] == FUNCTION


def is_atom(f):
    return f[0] == ATOM


def is_question(f):
    return f[0] == QUESTION


def is_term(f):
    return is_constant(f) or is_variable(f) or is_function_call(f)

def is_sentence(f):
    return is_atom(f) or f[0] == CONDITION


def has_args(f):
    return is_function_call(f) or is_sentence(f)


def get_value(f):
    if is_constant(f):
        return f[1]
    return None


def get_name(f):
    if is_variable(f):
        return f[1]
    return None


def get_head(f):
    if is_function_call(f) or is_atom(f):
        return f[1]
    if f[0] == CONDITION:
        return 'A'
    return None


def get_args(f):
    if has_args(f):
        return f[2]
    return []

def replace_args(formula, new_args):
    return (formula[0], formula[1], new_args)

def get_type(line):
    
    if line[0] == "?":
        return QUESTION
    elif ":" in line and line[0] != ":":
        return RULE
    elif line[0] == ":":
        return ANSWER
    else:
        return ATOM
        

facts = []
rules = []
questions = []

def process_atom(line):
    #elements_list = re.findall(r"[\w']+", line)
    #elements_list = re.findall(r',() ', line)
    #elements_list = re.findall('\[[^\]]*\]|\([^\)]*\)|\"[^\"]*\"|\S+', line)
    
    #elements_list = re.findall(r"[a-zA-Z0-9?()_*]+", line)
    #print(elements_list)
    #predicate = elements_list[0]
    #args = []  
    #for i in range(1, len(elements_list)):
        #if '?' in elements_list:
        
    predicate = ''
    current_string = ''
    for i in range(0, len(line)):
        if line[i] == ',':
            
        
        
        current_string = current_string + line[i]
            
    return make_atom(predicate, args)
        
def read_input(filename):
    
    f = open(filename, "r")
    for line in f:
        if line and line != '\n':
            full_line = line
            line = line.split()
            

            line_type = get_type(line)
            if line_type == ATOM:
                atom = process_atom(full_line)
                facts.append(atom)
                #print(atom[2])

    
    f.close()

            
            
            
read_input("teste/parsare.txt")
# Out:
# ['P(1)']
# ['P(2', 'U(3', 'V(4', '5)', '6)', '7)']
# ['Q(3)']
# ['t(?x)']
